# %% [markdown]
# # Sesión 3, Parte 1
#
# En esta sesión repasaremos un concepto que permite agregar código externo (y por ende, funcionalidades adicionales) a nuestro código. Para trabajar con datos, generalmente es necesario preparar nuestro computador instalando módulos (librerías) que no vienen por defecto en la instalación de Python. Hoy veremos cómo preparar el computador para eso.
#
# <p>
# <font size='1'>Material creado por &copy; 2024 José Tomás Marquinez, todos los derechos reservados; sacando algunos extractos del material elaborado por &copy; 2015 Karim Pichara - Christian Pieringer, todos los derechos reservados; y de las modificaciones realizadas por Equipos Docentes IIC2233 UC.</font>
# <br>

# %% [markdown]
# # Tabla de contenidos
#
# 1. Módulos externos
#     1. [Cómo encontrarlos](#como-encontrarlos)
#     2. [Cómo instalarlos](#como-instalarlos)
#     3. [Cómo usarlos](#como-usarlos)

# %% [markdown]
# # Módulos externos
#
# <a id="como-encontrarlos"></a>
#
# ## Cómo encontrarlos
#
# La primera pregunta que surge cuando estamos intentando trabajar con algo que no sabemos hacer, es cómo hacerlo. Y en ese sentido, siempre hay alguien que se hizo la misma pregunta.
#
# Para ilustrarlo con un ejemplo, supongamos que queremos trabajar con la base de datos de películas más completa de internet: [Internet Movie Database (IMDb)](https://www.imdb.com/). ¿Cómo podemos trabajar con esa base de datos desde Python?
#
# <style>
# .custom-image {
#   width: 600px;
#   height: auto;
#
# }
# </style>
#
# <center><img src="img/Google_search_IMDB.png" alt="image" class="custom-image"></center>
#
#
# Es generalmente la primera respuesta la que mejor explica cómo. Generalmente también ayuda informarse desde StackOverFlow, una comunidad en que los mismos integrantes de la comunidad responden las distintas dudas que tienen los que están buscando responder algo. Sin embargo, en esta ocasión, sigamos lo que nos dijo [la primera respuesta](https://www.geeksforgeeks.org/python-imdbpy-searching-a-movie/):
#
#
# <a id="como-instalarlos"></a>
#
# ## Cómo instalarlos
#
# En ese mismo sitio nos comentan que basta con escribir un comando en el _command prompt_ de nuestro computador, también conocida como la _consola_ o la _terminal_. Para abrir la terminal en nuestro computador, se puede hcaer lo siguiente:
#
# - Para Windows, se puede buscar por "Secuencia de comandos" o bien apretar Windows + X.
# - Para MacOS, se puede buscar por "Terminal". Para ello, es posible apretar Command + Espacio, y buscar "Terminal".
# - Para Linux, se puede apretar Ctrl + Alt + T, o averiguar cómo fue hecho eso en la distribución particular que estén usando.
#
# En el sitio web, nos indican que la instalación de cualquier paquete externo se puede hacer utilizando _*PIP*_. PIP es un nombre recursivo, que significa "Paquetes de instalación PIP" (_PIP Installs Packages_), o bien "Programa de Instalación Preferida". PIP es un sistema de administración de paquetes escrito para Python que permite instalar y administrar estos módulos externos. Si bien es posible instalar los módulos de otra forma, Python mismo sugiere utilizar este sistema para instalar módulos al trabajar, ya que se conecta a un repositorio online de paquetes públicos.
#
# Entonces, para instalar este módulo, el sitio web encontrado indica lo siguiente:
#
# <center><img src="img/pip_install.png" alt="image" class="custom-image"></center>
#
# En algunos ambientes de trabajo, se puede instalar directamente desde un Jupyter Notebook (desconozco si en todos los sistemas operativos). Esto se puede hacer programando esa línea con un caracter de escape `!`.

# %%
! pip install IMDbPY
# Out:
# Requirement already satisfied: IMDbPY in c:\users\jmarquinez\appdata\local\programs\python\python311\lib\site-packages (2022.7.9)
# Requirement already satisfied: cinemagoer in c:\users\jmarquinez\appdata\local\programs\python\python311\lib\site-packages (from IMDbPY) (2023.5.1)
# Requirement already satisfied: SQLAlchemy in c:\users\jmarquinez\appdata\local\programs\python\python311\lib\site-packages (from cinemagoer->IMDbPY) (2.0.15)
# Requirement already satisfied: lxml in c:\users\jmarquinez\appdata\local\programs\python\python311\lib\site-packages (from cinemagoer->IMDbPY) (4.9.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\jmarquinez\appdata\local\programs\python\python311\lib\site-packages (from SQLAlchemy->cinemagoer->IMDbPY) (4.10.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\jmarquinez\appdata\local\programs\python\python311\lib\site-packages (from SQLAlchemy->cinemagoer->IMDbPY) (2.0.2)

# %% [markdown]
# Esto, lo que hizo por detrás, es instalar un archivo llamado `imdb.py` en nuestro computador (en un directorio en donde se encuentran todos los módulos instalados), al que podemos hacer referencia posterior para usarlo. Este archivo contiene una clase `IMDb` que contiene métodos que permiten interactuar con la base de datos de IMDb.

# %% [markdown]
# <a id="como-usarlos"></a>
#
# ## Cómo usarlos
#
# Eso es todo. Todo lo que resta es **importar el módulo** instalado, leer la documentación y preguntarle muchas cosas a Google para responder cómo hacer lo que necesitamos hacer. La mayoría de los módulos que trabajan directamente con sistemas externos (`IMDbPY` con IMDb, `tweepy` con X, `instagram-explore` o `instabot` para Instagram, y muchos otros), suelen conectarse a algo que se conoce como una **API** (_Application Programming Interface_). En el mundo de las APIs, la palabra Aplicación refiere a cualquier programa que tiene una función particular, mientras que la palabra Interfaz se refiere a un contrato de un servicio entre dos aplicaciones. Este contrato define cómo se comunican estas dos aplicaciones entre sí utilizando solicitudes y respuestas (_requests_ y _responses_). Así, estos módulos lo que hacen es solicitarle información mediante una _request_ a un sitio (que tiene un _endpoint_ o URL específico para esto), y recibir la _response_ que contiene la información de respuesta.
#
# En particular, IMDbPy permite, por ejemplo, buscar todos los títulos de películas bajo cierto nombre. Sigamos lo que indica el tutorial, importando `imdb` (lo que importaría, a su vez, la clase implementada en ese archivo):

# %%
# importing the module
import imdb
# creating an instance of the IMDB()
ia = imdb.IMDb()
# Using the Search movie method
items = ia.search_movie('Avengers')
for i in items:
    print(i)
# Out:
# Avengers: Endgame
# The Avengers
# Avengers: Infinity War
# Avengers: Age of Ultron
# The Avengers
# Avengers: The Kang Dynasty
# Avengers: Secret Wars
# The Avengers
# Avengers Assemble
# Avengers: United They Stand
# Avengers: Quantum Encounter
# The New Avengers
# The Avengers: Earth's Mightiest Heroes
# Avengers of Justice: Farce Wars
# Avengers Grimm
# Ultimate Avengers: The Movie
# Crippled Avengers
# Marvel Future Avengers
# Next Avengers: Heroes of Tomorrow
# Lego Marvel Avengers: Code Red

# %% [markdown]
# También podemos, por ejemplo, extraer todas las películas en la que ha participado algún actor/actriz en particular. Sin embargo, esto es necesario hacerlo a través del ID de la persona (visible en la URL de su sitio en IMDb):
#
# <style>
# .custom-image-small {
#   width: 300px;
#   height: auto;
#
# }
# </style>
#
# <center><img src="img/emma_stone.png" alt="image" class="custom-image-small"></center>

# %% [markdown]
# O bien preguntándole a la API:

# %%
search_movie = ia.search_person('Emma Stone')
search_movie[0]
# Out:
# <Person id:1297015[http] name:_Emma Stone_>

# %%
# person id
code = "1297015"
 
# printing person name
print(ia.get_person(code))
# Out:
# Emma Stone

# %%
# getting information
actor_results = ia.get_person_filmography(code)
actor_results
# Out:
# {'data': {'filmography': {'actress': [<Movie id:14786246[http] title:_Cruella 2 (None)_>,
#     <Movie id:12300742[http] title:_Untitled Yorgos Lanthimos Remake Project (None)_>,
#     <Movie id:31176520[http] title:_Eddington (None)_>,
#     <Movie id:22408160[http] title:_Kinds of Kindness (2024)_>,
#     <Movie id:13623608[http] title:_The Curse (2024) (2023)_>,
#     <Movie id:14230458[http] title:_Poor Things (2023)_>,
#     <Movie id:11729844[http] title:_Bleat (2022)_>,
#     <Movie id:15977708[http] title:_Saturday Morning All Star Hits! (2021)_>,
#     <Movie id:3228774[http] title:_Cruella (2021)_>,
#     <Movie id:13972044[http] title:_Dear Diary: World's First Pranks (2021)_>,
#     <Movie id:2850386[http] title:_The Croods: A New Age (2020)_>,
#     <Movie id:11438728[http] title:_Louis Vuitton: Coeur Battant (2019)_>,
#     <Movie id:1560220[http] title:_Zombieland: Double Tap (2019)_>,
#     <Movie id:9471222[http] title:_Paul McCartney: Who Cares (2018)_>,
#     <Movie id:10177486[http] title:_Let's Dance (2018)_>,
#     <Movie id:5580146[http] title:_Maniac (2018)_>,
#     <Movie id:5083738[http] title:_The Favourite (2018)_>,
#     <Movie id:4622512[http] title:_Battle of the Sexes (2017)_>,
#     <Movie id:3783958[http] title:_La La Land (2016)_>,
#     <Movie id:5543284[http] title:_Maya & Marty (2016)_>,
#     <Movie id:3960412[http] title:_Popstar: Never Stop Never Stopping (2016)_>,
#     <Movie id:5708190[http] title:_Will Butler: Anna (2015)_>,
#     <Movie id:1243974[http] title:_Aloha (None)_>,
#     <Movie id:3715320[http] title:_Irrational Man (2015)_>,
#     <Movie id:2788710[http] title:_The Interview (None)_>,
#     <Movie id:2562232[http] title:_Birdman or (2014)_>,
#     <Movie id:22091270[http] title:_The Amazing Spider-Man 2: Deleted Scenes (2014)_>,
#     <Movie id:2870756[http] title:_Magic in the Moonlight (2014)_>,
#     <Movie id:30818022[http] title:_A Way In (2014)_>,
#     <Movie id:1872181[http] title:_The Amazing Spider-Man 2 (2014)_>,
#     <Movie id:0481499[http] title:_The Croods (2013)_>,
#     <Movie id:1321870[http] title:_Gangster Squad (2013)_>,
#     <Movie id:1333125[http] title:_Movie 43 (2013)_>,
#     <Movie id:22168494[http] title:_The Amazing Spider-Man: Deleted Scenes (2012)_>,
#     <Movie id:0972534[http] title:_iCarly (2012)_>,
#     <Movie id:2241982[http] title:_Sleeping Dogs (2012)_>,
#     <Movie id:0948470[http] title:_The Amazing Spider-Man (2012)_>,
#     <Movie id:0496424[http] title:_30 Rock (2012)_>,
#     <Movie id:1454029[http] title:_The Help (2011)_>,
#     <Movie id:1570728[http] title:_Crazy, Stupid, Love. (2011)_>,
#     <Movie id:1632708[http] title:_Friends with Benefits (2011)_>,
#     <Movie id:0437745[http] title:_Robot Chicken (2011)_>,
#     <Movie id:1282140[http] title:_Easy A (2010)_>,
#     <Movie id:1392197[http] title:_Marmaduke (2010)_>,
#     <Movie id:1156398[http] title:_Zombieland (2009)_>,
#     <Movie id:0437405[http] title:_Paper Man (2009)_>,
#     <Movie id:0821640[http] title:_Ghosts of Girlfriends Past (2009)_>,
#     <Movie id:0852713[http] title:_The House Bunny (2008)_>,
#     <Movie id:1031969[http] title:_The Rocker (2008)_>,
#     <Movie id:0770521[http] title:_Drive (2007)_>,
#     <Movie id:0829482[http] title:_Superbad (2007)_>,
#     <Movie id:0460619[http] title:_Lucky Louie (2006)_>,
#     <Movie id:0212671[http] title:_Malcolm in the Middle (2006)_>,
#     <Movie id:0426371[http] title:_The Suite Life of Zack & Cody (2006)_>,
#     <Movie id:0896990[http] title:_Untitled Oakley & Weinstein Project (2005)_>,
#     <Movie id:0412175[http] title:_Medium (2005)_>,
#     <Movie id:0444678[http] title:_The New Partridge Family (2005)_>],
#    'producer': [<Movie id:2018092[http] title:_Little White Corvette (None)_>,
#     <Movie id:14786246[http] title:_Cruella 2 (None)_>,
#     <Movie id:18182112[http] title:_Little Films (None)_>,
#     <Movie id:21823606[http] title:_A Real Pain (2024)_>,
#     <Movie id:15574270[http] title:_I Saw the TV Glow (2024)_>,
#     <Movie id:13623608[http] title:_The Curse (2024) (2023)_>,
#     <Movie id:14230458[http] title:_Poor Things (2023)_>,
#     <Movie id:15078804[http] title:_Problemista (2023)_>,
#     <Movie id:12121582[http] title:_When You Finish Saving the World (2022)_>,
#     <Movie id:3228774[http] title:_Cruella (2021)_>,
#     <Movie id:5580146[http] title:_Maniac (2018)_>],
#    'soundtrack': [<Movie id:3444938[http] title:_The Tonight Show Starring Jimmy Fallon (None)_>,
#     <Movie id:3783958[http] title:_La La Land (2016)_>,
#     <Movie id:0072562[http] title:_Saturday Night Live (2010)_>,
#     <Movie id:1282140[http] title:_Easy A (2010)_>],
#    'self': [<Movie id:15387926[http] title:_Dora the Explorer (2024)_>,
#     <Movie id:4202558[http] title:_Arte Journal (2024)_>,
#     <Movie id:0081857[http] title:_Entertainment Tonight (2024) (2008)_>,
#     <Movie id:0072506[http] title:_Good Morning America (2024) (2011)_>,
#     <Movie id:0462106[http] title:_Good Morning America Weekend Edition (2024)_>,
#     <Movie id:27590028[http] title:_The Oscars (2024)_>,
#     <Movie id:31707322[http] title:_The Oscars Red Carpet Show (2024)_>,
#     <Movie id:0167515[http] title:_Access Hollywood (2024) (2017)_>,
#     <Movie id:5106590[http] title:_IMDb Originals (2024)_>,
#     <Movie id:27785016[http] title:_The 30th Annual Screen Actors Guild Awards (2024)_>,
#     <Movie id:0486535[http] title:_Morgenmagazin (2024)_>,
#     <Movie id:31390646[http] title:_2024 EE BAFTA Film Awards (2024)_>,
#     <Movie id:3697842[http] title:_The Late Show with Stephen Colbert (2024) (2017)_>,
#     <Movie id:26424559[http] title:_Beau geste (2024)_>,
#     <Movie id:0165001[http] title:_CBS News Sunday Morning with Jane Pauley (2024) (2017)_>,
#     <Movie id:27801454[http] title:_The 29th Annual Critics' Choice Awards (2024)_>,
#     <Movie id:4267324[http] title:_Variety Studio: Actors on Actors (2024) (2017)_>,
#     <Movie id:30036660[http] title:_81st Golden Globe Awards (2024)_>,
#     <Movie id:0924651[http] title:_The Graham Norton Show (2023) (2014)_>,
#     <Movie id:6052530[http] title:_Quotidien (2023)_>,
#     <Movie id:12825566[http] title:_SmartLess (2023)_>,
#     <Movie id:0072562[http] title:_Saturday Night Live (2023) (2010)_>,
#     <Movie id:0320037[http] title:_Jimmy Kimmel Live! (2023) (2008)_>,
#     <Movie id:21599288[http] title:_Ari Global show (2022)_>,
#     <Movie id:19799706[http] title:_More than a Celebrity (2022)_>,
#     <Movie id:8638066[http] title:_Hollywood Insider (2022) (2021)_>,
#     <Movie id:9230898[http] title:_Conversation Hollywood (2021)_>,
#     <Movie id:0379623[http] title:_The Ellen DeGeneres Show (2021) (2012)_>,
#     <Movie id:0911896[http] title:_Made in Hollywood (2021) (2011)_>,
#     <Movie id:2049323[http] title:_The Jonathan Ross Show (2021)_>,
#     <Movie id:5825482[http] title:_Kermode and Mayo's Film Review (2021)_>,
#     <Movie id:14512490[http] title:_Showterview with Jessi (2021)_>,
#     <Movie id:14748656[http] title:_The Six O'Clock Show (2021)_>,
#     <Movie id:0298674[http] title:_Lorraine (2021) (2018)_>,
#     <Movie id:0096636[http] title:_Live with Kelly and Mark (2021) (2012)_>,
#     <Movie id:14739860[http] title:_The Jess Cagle Podcast with Julia Cunningham (2021)_>,
#     <Movie id:6587354[http] title:_Hollywood First Look (2021)_>,
#     <Movie id:3444938[http] title:_The Tonight Show Starring Jimmy Fallon (2020) (2014)_>,
#     <Movie id:12054924[http] title:_Some Good News (2020)_>,
#     <Movie id:10329132[http] title:_Celebrities with Heart (2020)_>,
#     <Movie id:8129446[http] title:_Lights Out with David Spade (2019)_>,
#     <Movie id:2070564[http] title:_WatchMojo (2019)_>,
#     <Movie id:10810430[http] title:_The Mind, Explained (2019)_>,
#     <Movie id:10624458[http] title:_My Favorite Shapes by Julio Torres (2019)_>,
#     <Movie id:7549864[http] title:_The IMDb Show (2019)_>,
#     <Movie id:9168816[http] title:_The Oscars (2019)_>,
#     <Movie id:9000560[http] title:_2019 Golden Globe Awards (2019)_>,
#     <Movie id:0482346[http] title:_Entertainment Tonight Canada (2018)_>,
#     <Movie id:3503424[http] title:_Celebrity Page (2018) (2017)_>,
#     <Movie id:8596744[http] title:_IMDb on the Scene - Interviews (2018)_>,
#     <Movie id:2163227[http] title:_CBS This Morning (2018)_>,
#     <Movie id:9005250[http] title:_Louis Vuitton: Attrape-Rêves - Where Will Your Journey Take You? (2018)_>,
#     <Movie id:9005314[http] title:_Louis Vuitton: The Spirit of Travel (2018)_>,
#     <Movie id:3644198[http] title:_Good Morning Britain (2018)_>,
#     <Movie id:7235270[http] title:_The Oscars (2018)_>,
#     <Movie id:4931888[http] title:_Close Up with the Hollywood Reporter (2018) (2017)_>,
#     <Movie id:8053828[http] title:_24th Annual Screen Actors Guild Awards (2018)_>,
#     <Movie id:7875148[http] title:_2018 Golden Globes Arrivals Special (2018)_>,
#     <Movie id:6635044[http] title:_75th Golden Globe Awards (2018)_>,
#     <Movie id:7918022[http] title:_One Day a Week (2017)_>,
#     <Movie id:5672036[http] title:_Chelsea (2017)_>,
#     <Movie id:3513388[http] title:_Late Night with Seth Meyers (2017)_>,
#     <Movie id:0044298[http] title:_Today (2017)_>,
#     <Movie id:5139360[http] title:_WGN Morning News (2017) (2016)_>,
#     <Movie id:15441582[http] title:_AFI Life Achievement Award (2017)_>,
#     <Movie id:8580028[http] title:_A Hero's Destiny: Behind 'The Amazing Spider-Man 2' (2017)_>,
#     <Movie id:8579574[http] title:_Exclusive Look Behind the Scenes of 'The Amazing Spider-Man' (2017)_>,
#     <Movie id:8579880[http] title:_The Amazing Spider-Man: A Rooftop View (2017)_>,
#     <Movie id:8580172[http] title:_The Amazing Spider-Man 2: Gwen and Peter (2017)_>,
#     <Movie id:0247094[http] title:_Extra (2017) (2014)_>,
#     <Movie id:4346344[http] title:_E! Live from the Red Carpet (2017) (2015)_>,
#     <Movie id:5850440[http] title:_The Oscars (2017)_>,
#     <Movie id:0430836[http] title:_The Insider (2017) (2014)_>,
#     <Movie id:6533268[http] title:_The EE British Academy Film Awards (2017)_>,
#     <Movie id:6634050[http] title:_The Envelope (2017)_>,
#     <Movie id:6435824[http] title:_The 23rd Annual Screen Actors Guild Awards (2017)_>,
#     <Movie id:5824900[http] title:_The 74th Annual Golden Globe Awards 2017 (2017)_>,
#     <Movie id:6265614[http] title:_David Blaine: Beyond Magic (2016)_>,
#     <Movie id:6688084[http] title:_The 19th Annual the Kennedy Center Mark Twain Prize for American Humor: Celebrating Bill Murray (2016)_>,
#     <Movie id:5220922[http] title:_73 Questions (2016)_>,
#     <Movie id:4896654[http] title:_Celebrity Conversations (2016)_>,
#     <Movie id:5816346[http] title:_Stand Up to Cancer (2016)_>,
#     <Movie id:5070048[http] title:_IMDb Asks (2015)_>,
#     <Movie id:5808766[http] title:_Remember That Time (2015)_>,
#     <Movie id:1637574[http] title:_Conan (2015) (2011)_>,
#     <Movie id:4577398[http] title:_2015 MTV Movie Awards (2015)_>,
#     <Movie id:4332122[http] title:_Nickelodeon Kids' Choice Awards 2015 (2015)_>,
#     <Movie id:3674910[http] title:_The Oscars (2015)_>,
#     <Movie id:4267078[http] title:_30th Annual Film Independent Spirit Awards (2015)_>,
#     <Movie id:3677742[http] title:_Saturday Night Live: 40th Anniversary Special (2015)_>,
#     <Movie id:4384904[http] title:_The 21st Annual Screen Actors Guild Awards (2015)_>,
#     <Movie id:3270224[http] title:_72nd Golden Globe Awards (2015)_>,
#     <Movie id:4944600[http] title:_Hollywood Sessions (2014)_>,
#     <Movie id:0106053[http] title:_Late Show with David Letterman (2014) (2010)_>,
#     <Movie id:3412000[http] title:_IMDb: What to Watch (2014)_>,
#     <Movie id:5123584[http] title:_Rencontres de cinéma (2014)_>,
#     <Movie id:1778943[http] title:_In Character with... (2014)_>,
#     <Movie id:0115147[http] title:_The Daily Show (2014)_>,
#     <Movie id:2787918[http] title:_Weekend Ticket (2014)_>,
#     <Movie id:3637130[http] title:_Heroes and Villains: The World of the Amazing Spider-Man (2014)_>,
#     <Movie id:1612376[http] title:_Janela Indiscreta (2014) (2011)_>,
#     <Movie id:0355143[http] title:_taff (2014) (2013)_>,
#     <Movie id:3524446[http] title:_Unscripted (2014)_>,
#     <Movie id:3578774[http] title:_2014 MTV Movie Awards (2014)_>,
#     <Movie id:0381753[http] title:_Fantastic (2014) (2012)_>,
#     <Movie id:0426701[http] title:_Le grand journal de Canal+ (2014)_>,
#     <Movie id:3262722[http] title:_71st Golden Globe Awards (2014)_>,
#     <Movie id:2576350[http] title:_Celebrity Style Story (2013)_>,
#     <Movie id:2865158[http] title:_Gangster Squad: Tough Guys with Style (2013)_>,
#     <Movie id:3110888[http] title:_Vivir de cine (2013)_>,
#     <Movie id:1907886[http] title:_Big Morning Buzz Live (2013) (2012)_>,
#     <Movie id:2723746[http] title:_Vanity Fair's Hollywood (2013)_>,
#     <Movie id:24155468[http] title:_Oscar Nominations 2013 (2013)_>,
#     <Movie id:2276210[http] title:_The Hollywood Fast Lane (2013)_>,
#     <Movie id:1434322[http] title:_Up Close with Carrie Keagan (2013) (2007)_>,
#     <Movie id:0103569[http] title:_The Tonight Show with Jay Leno (2013) (2008)_>,
#     <Movie id:2387576[http] title:_Rite of Passage: The Amazing Spider-Man Reborn (2012)_>,
#     <Movie id:2385182[http] title:_Stand Up to Cancer (2012)_>,
#     <Movie id:0870872[http] title:_El hormiguero (2012) (2010)_>,
#     <Movie id:2233044[http] title:_The Amazing Spider-Man T4 Premiere Special (2012)_>,
#     <Movie id:2226228[http] title:_A Moment With (2012)_>,
#     <Movie id:0270116[http] title:_Charlie Rose (2012)_>,
#     <Movie id:1231460[http] title:_Late Night with Jimmy Fallon (2012) (2009)_>,
#     <Movie id:2184336[http] title:_The 66th Annual Tony Awards (2012)_>,
#     <Movie id:2202980[http] title:_Guys Choice Awards 2012 (2012)_>,
#     <Movie id:2402919[http] title:_2012 MTV Movie Awards (2012)_>,
#     <Movie id:2199495[http] title:_Nickelodeon Kids' Choice Awards 2012 (2012)_>,
#     <Movie id:31158608[http] title:_Sleeping Dogs: Behind the Scenes (2012)_>,
#     <Movie id:2089826[http] title:_The 84th Annual Academy Awards (2012)_>,
#     <Movie id:2224007[http] title:_18th Annual Screen Actors Guild Awards (2012)_>,
#     <Movie id:2125640[http] title:_The 69th Annual Golden Globe Awards (2012)_>,
#     <Movie id:2184093[http] title:_17th Annual Critics' Choice Movie Awards (2012)_>,
#     <Movie id:2179173[http] title:_The 38th Annual People's Choice Awards (2012)_>,
#     <Movie id:0063951[http] title:_Sesame Street (2011)_>,
#     <Movie id:0390699[http] title:_Días de cine (2011) (2010)_>,
#     <Movie id:1908337[http] title:_The Big Picture (2011)_>,
#     <Movie id:1991198[http] title:_Teen Choice 2011 (2011)_>,
#     <Movie id:0094547[http] title:_Sidewalks Entertainment (2011)_>,
#     <Movie id:1924211[http] title:_2011 MTV Movie Awards (2011)_>,
#     <Movie id:1810776[http] title:_The 68th Annual Golden Globe Awards (2011)_>,
#     <Movie id:1817076[http] title:_16th Annual Critics' Choice Movie Awards (2011)_>,
#     <Movie id:1971384[http] title:_Easy A: The School of Pop Culture (2010)_>,
#     <Movie id:1967629[http] title:_The Making of Easy A (2010)_>,
#     <Movie id:1967658[http] title:_Vocabulary of Hilarity (2010)_>,
#     <Movie id:0827947[http] title:_Rachael Ray (2010)_>,
#     <Movie id:1002838[http] title:_Chelsea Lately (2010)_>,
#     <Movie id:1720618[http] title:_2010 MTV Video Music Awards (2010)_>,
#     <Movie id:1741714[http] title:_iPhone Murder Apps (2010)_>,
#     <Movie id:0111920[http] title:_Cinema 3 (2009)_>,
#     <Movie id:1356777[http] title:_Girls Upstairs: Making of 'House Bunny' (2008)_>,
#     <Movie id:1301718[http] title:_Spike Guys Choice (2008)_>,
#     <Movie id:1230105[http] title:_2008 MTV Movie Awards (2008)_>,
#     <Movie id:0305056[http] title:_Last Call with Carson Daly (2007)_>,
#     <Movie id:0408087[http] title:_In Search of the Partridge Family (2004)_>],
#    'archive footage': [<Movie id:22884836[http] title:_Valliant Renegade (2024)_>,
#     <Movie id:11465472[http] title:_Josiah Rises (2024)_>,
#     <Movie id:15054972[http] title:_Movie Night Extravaganza (2024) (2022)_>,
#     <Movie id:0081857[http] title:_Entertainment Tonight (2024) (2015)_>,
#     <Movie id:1480165[http] title:_The Project (2024)_>,
#     <Movie id:11719236[http] title:_Nudes in the News (2023)_>,
#     <Movie id:11101140[http] title:_Nerdrotic (2023)_>,
#     <Movie id:20115632[http] title:_What 16 Movies Looked Like Behind the Scenes in 2021 (2021)_>,
#     <Movie id:15277036[http] title:_Moments Within Moments (2021)_>,
#     <Movie id:11489716[http] title:_Inside Edition Weekend (2021)_>,
#     <Movie id:13990468[http] title:_Allen v. Farrow (2021)_>,
#     <Movie id:0096636[http] title:_Live with Kelly and Mark (2020) (2013)_>,
#     <Movie id:3503424[http] title:_Celebrity Page (2019) (2017)_>,
#     <Movie id:22506502[http] title:_Saturday Night Live Christmas Special (2019)_>,
#     <Movie id:9358228[http] title:_Untouchable (None)_>,
#     <Movie id:7329810[http] title:_The Bill Murray Stories: Life Lessons Learned from a Mythical Man (2018)_>,
#     <Movie id:3644198[http] title:_Good Morning Britain (2017)_>,
#     <Movie id:0247094[http] title:_Extra (2017) (2015)_>,
#     <Movie id:0430836[http] title:_The Insider (2017) (2016)_>,
#     <Movie id:0924651[http] title:_The Graham Norton Show (2017) (2014)_>,
#     <Movie id:0262152[http] title:_Breakfast (2017)_>,
#     <Movie id:0298674[http] title:_Lorraine (2017)_>,
#     <Movie id:4699262[http] title:_Nunca es tarde (2017)_>,
#     <Movie id:0167515[http] title:_Access Hollywood (2017)_>,
#     <Movie id:6436780[http] title:_Hoy nos toca (2017)_>,
#     <Movie id:1635327[http] title:_Nostalgia Critic (2016)_>,
#     <Movie id:0166442[http] title:_Inside Edition (2015)_>,
#     <Movie id:4460272[http] title:_An SNL Valentine (2015)_>,
#     <Movie id:2894120[http] title:_Flirting with Danger (2012)_>,
#     <Movie id:1908337[http] title:_The Big Picture (2011)_>]}},
#  'titlesRefs': {'Cruella 2': <Movie id:14786246[http] title:_Cruella 2 (None)_>,
#   'Untitled Yorgos Lanthimos Remake Project': <Movie id:12300742[http] title:_Untitled Yorgos Lanthimos Remake Project (None)_>,
#   'Eddington': <Movie id:31176520[http] title:_Eddington (None)_>,
#   'Kinds of Kindness': <Movie id:22408160[http] title:_Kinds of Kindness (None)_>,
#   'The Curse': <Movie id:13623608[http] title:_The Curse (None)_>,
#   'Green Queen (2024)': <Movie id:28679134[http] title:_Green Queen (2024)_>,
#   'Young Hearts (2024)': <Movie id:28679133[http] title:_Young Hearts (2024)_>,
#   'Down and Dirty (2023)': <Movie id:28679132[http] title:_Down and Dirty (2023)_>,
#   'Self-Exclusion (2023)': <Movie id:28679123[http] title:_Self-Exclusion (2023)_>,
#   'The Fire Burns On (2023)': <Movie id:28679121[http] title:_The Fire Burns On (2023)_>,
#   'Under the Big Tree (2023)': <Movie id:28679110[http] title:_Under the Big Tree (2023)_>,
#   'Questa Lane (2023)': <Movie id:28679090[http] title:_Questa Lane (2023)_>,
#   "Pressure's Looking Good So Far (2023)": <Movie id:28679078[http] title:_Pressure's Looking Good So Far (2023)_>,
#   "It's a Good Day (2023)": <Movie id:28679112[http] title:_It's a Good Day (2023)_>,
#   'Land of Enchantment (2023)': <Movie id:15120944[http] title:_Land of Enchantment (2023)_>,
#   'Poor Things': <Movie id:14230458[http] title:_Poor Things (None)_>,
#   'Bleat': <Movie id:11729844[http] title:_Bleat (None)_>,
#   'Saturday Morning All Star Hits!': <Movie id:15977708[http] title:_Saturday Morning All Star Hits! (None)_>,
#   'Tape 6: MOVIE (2021)': <Movie id:16234686[http] title:_Tape 6: MOVIE (2021)_>,
#   'Tape 4: SMASH! (2021)': <Movie id:16234682[http] title:_Tape 4: SMASH! (2021)_>,
#   'Tape 3: ZOO (2021)': <Movie id:16234680[http] title:_Tape 3: ZOO (2021)_>,
#   'Tape 2: LOST (2021)': <Movie id:16234678[http] title:_Tape 2: LOST (2021)_>,
#   'Tape 1: SCHOOL (2021)': <Movie id:16234676[http] title:_Tape 1: SCHOOL (2021)_>,
#   'Cruella': <Movie id:3228774[http] title:_Cruella (None)_>,
#   "Dear Diary: World's First Pranks": <Movie id:13972044[http] title:_Dear Diary: World's First Pranks (None)_>,
#   'The Croods: A New Age': <Movie id:2850386[http] title:_The Croods: A New Age (None)_>,
#   'Louis Vuitton: Coeur Battant': <Movie id:11438728[http] title:_Louis Vuitton: Coeur Battant (None)_>,
#   'Zombieland: Double Tap': <Movie id:1560220[http] title:_Zombieland: Double Tap (None)_>,
#   'Paul McCartney: Who Cares': <Movie id:9471222[http] title:_Paul McCartney: Who Cares (None)_>,
#   "Let's Dance": <Movie id:10177486[http] title:_Let's Dance (None)_>,
#   'Maniac': <Movie id:5580146[http] title:_Maniac (None)_>,
#   'The Lake of the Clouds (2018)': <Movie id:7741834[http] title:_The Lake of the Clouds (2018)_>,
#   'Larger Structural Issues (2018)': <Movie id:7741826[http] title:_Larger Structural Issues (2018)_>,
#   'Utangatta (2018)': <Movie id:7722652[http] title:_Utangatta (2018)_>,
#   'Exactly Like You (2018)': <Movie id:7670110[http] title:_Exactly Like You (2018)_>,
#   'Furs by Sebastian (2018)': <Movie id:7670108[http] title:_Furs by Sebastian (2018)_>,
#   "Ceci N'est Pas Une Drill (2018)": <Movie id:7449916[http] title:_Ceci N'est Pas Une Drill (2018)_>,
#   'Having a Day (2018)': <Movie id:7317152[http] title:_Having a Day (2018)_>,
#   'Option C (2018)': <Movie id:6509000[http] title:_Option C (2018)_>,
#   'Windmills (2018)': <Movie id:5611830[http] title:_Windmills (2018)_>,
#   'The Chosen One! (2018)': <Movie id:5611650[http] title:_The Chosen One! (2018)_>,
#   'The Favourite': <Movie id:5083738[http] title:_The Favourite (None)_>,
#   'Battle of the Sexes': <Movie id:4622512[http] title:_Battle of the Sexes (None)_>,
#   'La La Land': <Movie id:3783958[http] title:_La La Land (None)_>,
#   'Maya & Marty': <Movie id:5543284[http] title:_Maya & Marty (None)_>,
#   'Sean Hayes, Steve Martin, Kelly Ripa & Emma Stone (2016)': <Movie id:5831802[http] title:_Sean Hayes, Steve Martin, Kelly Ripa & Emma Stone (2016)_>,
#   'Popstar: Never Stop Never Stopping': <Movie id:3960412[http] title:_Popstar: Never Stop Never Stopping (None)_>,
#   'Will Butler: Anna': <Movie id:5708190[http] title:_Will Butler: Anna (None)_>,
#   'Aloha': <Movie id:1243974[http] title:_Aloha (None)_>,
#   'Irrational Man': <Movie id:3715320[http] title:_Irrational Man (None)_>,
#   'The Interview': <Movie id:2788710[http] title:_The Interview (None)_>,
#   'Birdman or (The Unexpected Virtue of Ignorance)': <Movie id:2562232[http] title:_Birdman or (The Unexpected Virtue of Ignorance) (None)_>,
#   'The Amazing Spider-Man 2: Deleted Scenes': <Movie id:22091270[http] title:_The Amazing Spider-Man 2: Deleted Scenes (None)_>,
#   'Magic in the Moonlight': <Movie id:2870756[http] title:_Magic in the Moonlight (None)_>,
#   'A Way In': <Movie id:30818022[http] title:_A Way In (None)_>,
#   'The Amazing Spider-Man 2': <Movie id:1872181[http] title:_The Amazing Spider-Man 2 (None)_>,
#   'The Croods': <Movie id:0481499[http] title:_The Croods (None)_>,
#   'Gangster Squad': <Movie id:1321870[http] title:_Gangster Squad (None)_>,
#   'Movie 43': <Movie id:1333125[http] title:_Movie 43 (None)_>,
#   'The Amazing Spider-Man: Deleted Scenes': <Movie id:22168494[http] title:_The Amazing Spider-Man: Deleted Scenes (None)_>,
#   'iCarly': <Movie id:0972534[http] title:_iCarly (None)_>,
#   'iFind Spencer Friends (2012)': <Movie id:2470918[http] title:_iFind Spencer Friends (2012)_>,
#   'Sleeping Dogs': <Movie id:2241982[http] title:_Sleeping Dogs (None)_>,
#   'The Amazing Spider-Man': <Movie id:0948470[http] title:_The Amazing Spider-Man (None)_>,
#   '30 Rock': <Movie id:0496424[http] title:_30 Rock (None)_>,
#   'The Ballad of Kenneth Parcell (2012)': <Movie id:2191917[http] title:_The Ballad of Kenneth Parcell (2012)_>,
#   'The Help': <Movie id:1454029[http] title:_The Help (None)_>,
#   'Crazy, Stupid, Love.': <Movie id:1570728[http] title:_Crazy, Stupid, Love. (None)_>,
#   'Friends with Benefits': <Movie id:1632708[http] title:_Friends with Benefits (None)_>,
#   'Robot Chicken': <Movie id:0437745[http] title:_Robot Chicken (None)_>,
#   'Catch Me If You Kangaroo Jack (2011)': <Movie id:1821998[http] title:_Catch Me If You Kangaroo Jack (2011)_>,
#   'No Country for Old Dogs (2011)': <Movie id:1822002[http] title:_No Country for Old Dogs (2011)_>,
#   'Easy A': <Movie id:1282140[http] title:_Easy A (None)_>,
#   'Marmaduke': <Movie id:1392197[http] title:_Marmaduke (None)_>,
#   'Zombieland': <Movie id:1156398[http] title:_Zombieland (None)_>,
#   'Paper Man': <Movie id:0437405[http] title:_Paper Man (None)_>,
#   'Ghosts of Girlfriends Past': <Movie id:0821640[http] title:_Ghosts of Girlfriends Past (None)_>,
#   'The House Bunny': <Movie id:0852713[http] title:_The House Bunny (None)_>,
#   'The Rocker': <Movie id:1031969[http] title:_The Rocker (None)_>,
#   'Drive': <Movie id:0770521[http] title:_Drive (None)_>,
#   'Unaired Pilot (2007)': <Movie id:0792531[http] title:_Unaired Pilot (2007)_>,
#   'Rearview (2007)': <Movie id:1004183[http] title:_Rearview (2007)_>,
#   'The Extra Mile (2007)': <Movie id:0989988[http] title:_The Extra Mile (2007)_>,
#   'No Turning Back (2007)': <Movie id:0993189[http] title:_No Turning Back (2007)_>,
#   'Let the Games Begin (2007)': <Movie id:0989181[http] title:_Let the Games Begin (2007)_>,
#   'Partners (2007)': <Movie id:0964786[http] title:_Partners (2007)_>,
#   'The Starting Line (2007)': <Movie id:0921947[http] title:_The Starting Line (2007)_>,
#   'Superbad': <Movie id:0829482[http] title:_Superbad (None)_>,
#   'Lucky Louie': <Movie id:0460619[http] title:_Lucky Louie (None)_>,
#   'Get Out (2006)': <Movie id:0637373[http] title:_Get Out (2006)_>,
#   'Malcolm in the Middle': <Movie id:0212671[http] title:_Malcolm in the Middle (None)_>,
#   'Lois Strikes Back (2006)': <Movie id:0640357[http] title:_Lois Strikes Back (2006)_>,
#   'The Suite Life of Zack & Cody': <Movie id:0426371[http] title:_The Suite Life of Zack & Cody (None)_>,
#   'Crushed (2006)': <Movie id:0712948[http] title:_Crushed (2006)_>,
#   'Untitled Oakley & Weinstein Project': <Movie id:0896990[http] title:_Untitled Oakley & Weinstein Project (None)_>,
#   'Medium': <Movie id:0412175[http] title:_Medium (None)_>,
#   'Sweet Dreams (2005)': <Movie id:0645633[http] title:_Sweet Dreams (2005)_>,
#   'The New Partridge Family': <Movie id:0444678[http] title:_The New Partridge Family (None)_>,
#   'Little White Corvette': <Movie id:2018092[http] title:_Little White Corvette (None)_>,
#   'Little Films': <Movie id:18182112[http] title:_Little Films (None)_>,
#   'A Real Pain': <Movie id:21823606[http] title:_A Real Pain (None)_>,
#   'I Saw the TV Glow': <Movie id:15574270[http] title:_I Saw the TV Glow (None)_>,
#   'Problemista': <Movie id:15078804[http] title:_Problemista (None)_>,
#   'When You Finish Saving the World': <Movie id:12121582[http] title:_When You Finish Saving the World (None)_>,
#   'The Tonight Show Starring Jimmy Fallon': <Movie id:3444938[http] title:_The Tonight Show Starring Jimmy Fallon (None)_>,
#   'Emma Stone/Jeffrey Dean Morgan/Kacey Musgraves (2016)': <Movie id:6282404[http] title:_Emma Stone/Jeffrey Dean Morgan/Kacey Musgraves (2016)_>,
#   'Emma Stone/Robinson Cano/Keith Urban (2014)': <Movie id:3677252[http] title:_Emma Stone/Robinson Cano/Keith Urban (2014)_>,
#   'Saturday Night Live': <Movie id:0072562[http] title:_Saturday Night Live (None)_>,
#   'Emma Stone/Kings of Leon (2010)': <Movie id:1729476[http] title:_Emma Stone/Kings of Leon (2010)_>,
#   'Dora the Explorer': <Movie id:15387926[http] title:_Dora the Explorer (None)_>,
#   'Episode #1.11': <Movie id:15395358[http] title:_Episode #1.11 (None)_>,
#   'Arte Journal': <Movie id:4202558[http] title:_Arte Journal (None)_>,
#   'Arte Journal vom 11.03.2024 (2024)': <Movie id:31702755[http] title:_Arte Journal vom 11.03.2024 (2024)_>,
#   'Entertainment Tonight': <Movie id:0081857[http] title:_Entertainment Tonight (None)_>,
#   'ET at the Oscars! (2024)': <Movie id:31624504[http] title:_ET at the Oscars! (2024)_>,
#   'Episode #43.105 (2024)': <Movie id:30807187[http] title:_Episode #43.105 (2024)_>,
#   'Episode #43.103 (2024)': <Movie id:30807182[http] title:_Episode #43.103 (2024)_>,
#   'Episode #43.101 (2024)': <Movie id:30743906[http] title:_Episode #43.101 (2024)_>,
#   'Episode #43.87 (2023)': <Movie id:30471201[http] title:_Episode #43.87 (2023)_>,
#   'Episode #43.77 (2023)': <Movie id:30274060[http] title:_Episode #43.77 (2023)_>,
#   'Episode #43.76 (2023)': <Movie id:30274056[http] title:_Episode #43.76 (2023)_>,
#   'Episode #40.212 (2021)': <Movie id:14658176[http] title:_Episode #40.212 (2021)_>,
#   'Episode #40.211 (2021)': <Movie id:14658174[http] title:_Episode #40.211 (2021)_>,
#   'Episode #40.200 (2021)': <Movie id:14563110[http] title:_Episode #40.200 (2021)_>,
#   'ET Exclusives! (2020)': <Movie id:13510940[http] title:_ET Exclusives! (2020)_>,
#   'Episode #40.55 (2020)': <Movie id:13465402[http] title:_Episode #40.55 (2020)_>,
#   'Episode #39.29 (2019)': <Movie id:11070482[http] title:_Episode #39.29 (2019)_>,
#   "ET's Oscar Monday Blowout! (2019)": <Movie id:9828360[http] title:_ET's Oscar Monday Blowout! (2019)_>,
#   'Episode #38.58 (2018)': <Movie id:9261904[http] title:_Episode #38.58 (2018)_>,
#   'Episode #38.11 (2018)': <Movie id:9030410[http] title:_Episode #38.11 (2018)_>,
#   'Episode #38.2 (2018)': <Movie id:8968140[http] title:_Episode #38.2 (2018)_>,
#   'Episode #37.99 (2018)': <Movie id:7799812[http] title:_Episode #37.99 (2018)_>,
#   'Episode #37.8 (2017)': <Movie id:7380986[http] title:_Episode #37.8 (2017)_>,
#   'Episode #36.136 (2017)': <Movie id:6528186[http] title:_Episode #36.136 (2017)_>,
#   'Episode #36.127 (2017)': <Movie id:6496870[http] title:_Episode #36.127 (2017)_>,
#   'Episode #36.121 (2017)': <Movie id:6451220[http] title:_Episode #36.121 (2017)_>,
#   'Episode #36.103 (2017)': <Movie id:6374636[http] title:_Episode #36.103 (2017)_>,
#   'Episode #36.97 (2017)': <Movie id:6374620[http] title:_Episode #36.97 (2017)_>,
#   'Episode #36.75 (2016)': <Movie id:6288772[http] title:_Episode #36.75 (2016)_>,
#   'Episode #36.74 (2016)': <Movie id:6288766[http] title:_Episode #36.74 (2016)_>,
#   'Episode #36.57 (2016)': <Movie id:5798140[http] title:_Episode #36.57 (2016)_>,
#   'Episode #35.262 (2016)': <Movie id:6051248[http] title:_Episode #35.262 (2016)_>,
#   'Episode #35.254 (2016)': <Movie id:6015240[http] title:_Episode #35.254 (2016)_>,
#   'Episode dated 9 July 2015 (2015)': <Movie id:4829908[http] title:_Episode dated 9 July 2015 (2015)_>,
#   'Episode dated 18 May 2015 (2015)': <Movie id:4661002[http] title:_Episode dated 18 May 2015 (2015)_>,
#   'Episode dated 28 April 2015 (2015)': <Movie id:4631824[http] title:_Episode dated 28 April 2015 (2015)_>,
#   'Episode dated 5 May 2014 (2014)': <Movie id:3707218[http] title:_Episode dated 5 May 2014 (2014)_>,
#   'Episode dated 3 May 2014 (2014)': <Movie id:3693058[http] title:_Episode dated 3 May 2014 (2014)_>,
#   'Episode dated 2 May 2014 (2014)': <Movie id:3693028[http] title:_Episode dated 2 May 2014 (2014)_>,
#   'Episode dated 25 April 2014 (2014)': <Movie id:3677772[http] title:_Episode dated 25 April 2014 (2014)_>,
#   'Episode dated 19 April 2014 (2014)': <Movie id:3664070[http] title:_Episode dated 19 April 2014 (2014)_>,
#   'Episode dated 15 April 2014 (2014)': <Movie id:3664054[http] title:_Episode dated 15 April 2014 (2014)_>,
#   'Episode dated 14 September 2010 (2010)': <Movie id:1717838[http] title:_Episode dated 14 September 2010 (2010)_>,
#   'Episode dated 19 August 2008 (2008)': <Movie id:1450307[http] title:_Episode dated 19 August 2008 (2008)_>,
#   'Good Morning America': <Movie id:0072506[http] title:_Good Morning America (None)_>,
#   'Joe Zee/Bevy Smith/Kahlana Barfield Brown/Christopher Palu/Paul Russell (2024)': <Movie id:31549764[http] title:_Joe Zee/Bevy Smith/Kahlana Barfield Brown/Christopher Palu/Paul Russell (2024)_>,
#   "Emma Stone/Megan Thee Stallion/Bryce Dallas Howard & Catherine O'Hara/ (2024)": <Movie id:31069812[http] title:_Emma Stone/Megan Thee Stallion/Bryce Dallas Howard & Catherine O'Hara/ (2024)_>,
#   'Episode dated 25 May 2021 (2021)': <Movie id:14740288[http] title:_Episode dated 25 May 2021 (2021)_>,
#   'Episode dated 19 September 2018 (2018)': <Movie id:8913272[http] title:_Episode dated 19 September 2018 (2018)_>,
#   'Episode dated 28 November 2016 (2016)': <Movie id:6265890[http] title:_Episode dated 28 November 2016 (2016)_>,
#   'Episode dated 13 July 2015 (2015)': <Movie id:4819202[http] title:_Episode dated 13 July 2015 (2015)_>,
#   'Episode dated 17 October 2014 (2014)': <Movie id:4086476[http] title:_Episode dated 17 October 2014 (2014)_>,
#   'Episode dated 15 October 2014 (2014)': <Movie id:4081136[http] title:_Episode dated 15 October 2014 (2014)_>,
#   'Episode dated 16 July 2014 (2014)': <Movie id:3846024[http] title:_Episode dated 16 July 2014 (2014)_>,
#   'Episode dated 10 January 2013 (2013)': <Movie id:2613540[http] title:_Episode dated 10 January 2013 (2013)_>,
#   'Episode dated 4 August 2011 (2011)': <Movie id:2007654[http] title:_Episode dated 4 August 2011 (2011)_>,
#   'Good Morning America Weekend Edition': <Movie id:0462106[http] title:_Good Morning America Weekend Edition (None)_>,
#   'Episode dated 10 March 2024 (2024)': <Movie id:31531647[http] title:_Episode dated 10 March 2024 (2024)_>,
#   'The Oscars': <Movie id:3674910[http] title:_The Oscars (None)_>,
#   'The Oscars Red Carpet Show': <Movie id:31707322[http] title:_The Oscars Red Carpet Show (None)_>,
#   'Access Hollywood': <Movie id:0167515[http] title:_Access Hollywood (None)_>,
#   'Episode #28.153 (2024)': <Movie id:31548134[http] title:_Episode #28.153 (2024)_>,
#   'Episode #28.79 (2023)': <Movie id:30395451[http] title:_Episode #28.79 (2023)_>,
#   'Episode #25.220 (2021)': <Movie id:14706588[http] title:_Episode #25.220 (2021)_>,
#   'Episode #22.8 (2017)': <Movie id:7350806[http] title:_Episode #22.8 (2017)_>,
#   'IMDb Originals': <Movie id:5106590[http] title:_IMDb Originals (None)_>,
#   '10 Women at the Top of Their Game in 2024 (2024)': <Movie id:31492470[http] title:_10 Women at the Top of Their Game in 2024 (2024)_>,
#   'The 30th Annual Screen Actors Guild Awards': <Movie id:27785016[http] title:_The 30th Annual Screen Actors Guild Awards (None)_>,
#   'Morgenmagazin': <Movie id:0486535[http] title:_Morgenmagazin (None)_>,
#   'ZDF Morgenmagazin vom 19.02.2024 (2024)': <Movie id:31827836[http] title:_ZDF Morgenmagazin vom 19.02.2024 (2024)_>,
#   '2024 EE BAFTA Film Awards': <Movie id:31390646[http] title:_2024 EE BAFTA Film Awards (None)_>,
#   'The Late Show with Stephen Colbert': <Movie id:3697842[http] title:_The Late Show with Stephen Colbert (None)_>,
#   'Emma Stone/Jaime Harrison (2024)': <Movie id:30576802[http] title:_Emma Stone/Jaime Harrison (2024)_>,
#   'Emma Stone/Flight of the Conchords (2018)': <Movie id:9034848[http] title:_Emma Stone/Flight of the Conchords (2018)_>,
#   'Hillary Clinton/Emma Stone (2017)': <Movie id:7382886[http] title:_Hillary Clinton/Emma Stone (2017)_>,
#   'Beau geste': <Movie id:26424559[http] title:_Beau geste (None)_>,
#   'Episode #2.14 (2024)': <Movie id:31014058[http] title:_Episode #2.14 (2024)_>,
#   'CBS News Sunday Morning with Jane Pauley': <Movie id:0165001[http] title:_CBS News Sunday Morning with Jane Pauley (None)_>,
#   'Episode #46.3 (2024)': <Movie id:30956416[http] title:_Episode #46.3 (2024)_>,
#   'Episode dated 12 February 2017 (2017)': <Movie id:6478384[http] title:_Episode dated 12 February 2017 (2017)_>,
#   "The 29th Annual Critics' Choice Awards": <Movie id:27801454[http] title:_The 29th Annual Critics' Choice Awards (None)_>,
#   'Variety Studio: Actors on Actors': <Movie id:4267324[http] title:_Variety Studio: Actors on Actors (None)_>,
#   'Cillian Murphy, Margot Robbie, Bradley Cooper & Emma Stone (2024)': <Movie id:30851105[http] title:_Cillian Murphy, Margot Robbie, Bradley Cooper & Emma Stone (2024)_>,
#   'Episode #9.2 (2019)': <Movie id:10436296[http] title:_Episode #9.2 (2019)_>,
#   'Episode #5.1 (2017)': <Movie id:6294034[http] title:_Episode #5.1 (2017)_>,
#   '81st Golden Globe Awards': <Movie id:30036660[http] title:_81st Golden Globe Awards (None)_>,
#   'The Graham Norton Show': <Movie id:0924651[http] title:_The Graham Norton Show (None)_>,
#   'Emma Stone/Mark Ruffalo/Claudia Winkleman/Rob Brydon/Ezra Collective (2023)': <Movie id:30399612[http] title:_Emma Stone/Mark Ruffalo/Claudia Winkleman/Rob Brydon/Ezra Collective (2023)_>,
#   'Eddie Redmayne/Jude Law/Melissa McCarthy/Emma Stone/Rick Astley (2018)': <Movie id:9114034[http] title:_Eddie Redmayne/Jude Law/Melissa McCarthy/Emma Stone/Rick Astley (2018)_>,
#   'Ben Affleck/Sienna Miller/Emma Stone/Ryan Gosling/Gregory Porter (2017)': <Movie id:6423868[http] title:_Ben Affleck/Sienna Miller/Emma Stone/Ryan Gosling/Gregory Porter (2017)_>,
#   'Andrew Garfield/Emma Stone/Jamie Foxx/Paolo Nutini (2014)': <Movie id:3663498[http] title:_Andrew Garfield/Emma Stone/Jamie Foxx/Paolo Nutini (2014)_>,
#   'Quotidien': <Movie id:6052530[http] title:_Quotidien (None)_>,
#   'Episode dated 11 December 2023 (2023)': <Movie id:30470607[http] title:_Episode dated 11 December 2023 (2023)_>,
#   'SmartLess': <Movie id:12825566[http] title:_SmartLess (None)_>,
#   'Emma Stone (2023)': <Movie id:30280160[http] title:_Emma Stone (2023)_>,
#   'Emma Stone/Noah Kahan (2023)': <Movie id:30057116[http] title:_Emma Stone/Noah Kahan (2023)_>,
#   'Emma Stone/BTS (2019)': <Movie id:10023578[http] title:_Emma Stone/BTS (2019)_>,
#   'Ryan Gosling/Jay-Z (2017)': <Movie id:7450578[http] title:_Ryan Gosling/Jay-Z (2017)_>,
#   'Emma Stone/Shawn Mendes (2016)': <Movie id:6261252[http] title:_Emma Stone/Shawn Mendes (2016)_>,
#   'Matthew McConaughey/Adele (2015)': <Movie id:5182368[http] title:_Matthew McConaughey/Adele (2015)_>,
#   'Andrew Garfield/Coldplay (2014)': <Movie id:3686908[http] title:_Andrew Garfield/Coldplay (2014)_>,
#   'Emma Stone/Coldplay (2011)': <Movie id:2088490[http] title:_Emma Stone/Coldplay (2011)_>,
#   'Jimmy Kimmel Live!': <Movie id:0320037[http] title:_Jimmy Kimmel Live! (None)_>,
#   'Emma Stone/Nathan Fielder/Paul Mescal/Laufey (2023)': <Movie id:29631099[http] title:_Emma Stone/Nathan Fielder/Paul Mescal/Laufey (2023)_>,
#   'Emma Stone/Rory Scovel/Chloe Moriando (2021)': <Movie id:14697126[http] title:_Emma Stone/Rory Scovel/Chloe Moriando (2021)_>,
#   'Regina King/Nat Wolff/Jimmy Eat World (2019)': <Movie id:11064126[http] title:_Regina King/Nat Wolff/Jimmy Eat World (2019)_>,
#   'Emma Stone/Danny Amendola/MUNA (2017)': <Movie id:6420744[http] title:_Emma Stone/Danny Amendola/MUNA (2017)_>,
#   'Kobe Bryant/Kenny G & Warren G (2015)': <Movie id:4467392[http] title:_Kobe Bryant/Kenny G & Warren G (2015)_>,
#   'Emma Stone/Jeff Perry/Schoolboy Q (2014)': <Movie id:3622480[http] title:_Emma Stone/Jeff Perry/Schoolboy Q (2014)_>,
#   'Episode #6.115 (2008)': <Movie id:1282910[http] title:_Episode #6.115 (2008)_>,
#   'Ari Global show': <Movie id:21599288[http] title:_Ari Global show (None)_>,
#   'A-list Interviews 2 (2022)': <Movie id:22476138[http] title:_A-list Interviews 2 (2022)_>,
#   'More than a Celebrity': <Movie id:19799706[http] title:_More than a Celebrity (None)_>,
#   'More Than a Celebrity: Emma Stone (2022)': <Movie id:21602990[http] title:_More Than a Celebrity: Emma Stone (2022)_>,
#   'Hollywood Insider': <Movie id:8638066[http] title:_Hollywood Insider (None)_>,
#   "A Tribute to Michael Keaton: Recounting the SAG Award Winning Actor's Iconic Roles (2022)": <Movie id:23140504[http] title:_A Tribute to Michael Keaton: Recounting the SAG Award Winning Actor's Iconic Roles (2022)_>,
#   'Oscars and Sad Movies: What Happened to the Uplifting Awards Contenders? - Academy Awards (2022)': <Movie id:23140114[http] title:_Oscars and Sad Movies: What Happened to the Uplifting Awards Contenders? - Academy Awards (2022)_>,
#   'The Few Times Humorists Have Scored Academy Gold: A Short List of Comedic Oscar-Winners (2022)': <Movie id:22496212[http] title:_The Few Times Humorists Have Scored Academy Gold: A Short List of Comedic Oscar-Winners (2022)_>,
#   'The Fascination with the Wicked - Why do Villains Reign in Current Film Pop Culture? (2022)': <Movie id:22496156[http] title:_The Fascination with the Wicked - Why do Villains Reign in Current Film Pop Culture? (2022)_>,
#   'The Rise and Journey of Jonah Hill - Actor, Writer, Director (2022)': <Movie id:22496002[http] title:_The Rise and Journey of Jonah Hill - Actor, Writer, Director (2022)_>,
#   'An Ode to the Undead: A History of Zombie Movies from George Romero to Zack Snyder (2021)': <Movie id:22296990[http] title:_An Ode to the Undead: A History of Zombie Movies from George Romero to Zack Snyder (2021)_>,
#   "Full Commentary & Behind the Scenes of 'Cruella' Reactions - Emma Stone, Emma Thompson (2021)": <Movie id:22060892[http] title:_Full Commentary & Behind the Scenes of 'Cruella' Reactions - Emma Stone, Emma Thompson (2021)_>,
#   "Cruella' Rendezvous At The Premiere Reactions with Emma Stone, Cast and Crew (2021)": <Movie id:22060842[http] title:_Cruella' Rendezvous At The Premiere Reactions with Emma Stone, Cast and Crew (2021)_>,
#   'Movies About Making Movies: A Ranking of the Ten Best Movies That Peek Behind the Cinematic Curtain (2021)': <Movie id:22060802[http] title:_Movies About Making Movies: A Ranking of the Ten Best Movies That Peek Behind the Cinematic Curtain (2021)_>,
#   'The Rise and Journey of Emma Stone: This Oscar Winner Excels in Both Comedy and Drama (2021)': <Movie id:22060360[http] title:_The Rise and Journey of Emma Stone: This Oscar Winner Excels in Both Comedy and Drama (2021)_>,
#   "Keeping In Rhythm with Damien Chazelle: The Fantastically Talented Oscar Winning Director's Movies (2021)": <Movie id:22052634[http] title:_Keeping In Rhythm with Damien Chazelle: The Fantastically Talented Oscar Winning Director's Movies (2021)_>,
#   'Myers-Briggs Goes Hollywood: Which Movie & TV Characters Are the Same As Your Personality Type? (2021)': <Movie id:21960070[http] title:_Myers-Briggs Goes Hollywood: Which Movie & TV Characters Are the Same As Your Personality Type? (2021)_>,
#   'Jessica Chastain Facts: 32 Things You Might Know About This Stunning and Talented Actress (2021)': <Movie id:14518812[http] title:_Jessica Chastain Facts: 32 Things You Might Know About This Stunning and Talented Actress (2021)_>,
#   'Conversation Hollywood': <Movie id:9230898[http] title:_Conversation Hollywood (None)_>,
#   'Emma Stone (2021)': <Movie id:14691908[http] title:_Emma Stone (2021)_>,
#   'The Ellen DeGeneres Show': <Movie id:0379623[http] title:_The Ellen DeGeneres Show (None)_>,
#   'Emma Stone/Ziwe/Mimi Webb (2021)': <Movie id:14753422[http] title:_Emma Stone/Ziwe/Mimi Webb (2021)_>,
#   "Ellen's 12 Days of Giveaways (2016)": <Movie id:6227622[http] title:_Ellen's 12 Days of Giveaways (2016)_>,
#   'Andrew Garfield/Emma Stone/Jamie Foxx (2014)': <Movie id:3590532[http] title:_Andrew Garfield/Emma Stone/Jamie Foxx (2014)_>,
#   'Episode #10.79 (2013)': <Movie id:2597430[http] title:_Episode #10.79 (2013)_>,
#   'Episode #9.131 (2012)': <Movie id:2320421[http] title:_Episode #9.131 (2012)_>,
#   'Made in Hollywood': <Movie id:0911896[http] title:_Made in Hollywood (None)_>,
#   'Cruella/The Kominsky Method/Panic (2021)': <Movie id:18328524[http] title:_Cruella/The Kominsky Method/Panic (2021)_>,
#   'Kingsman: The Golden Circle/The LEGO Ninjago Movie/Battle of the Sexes/Victoria & Abdul (2017)': <Movie id:2319263[http] title:_Kingsman: The Golden Circle/The LEGO Ninjago Movie/Battle of the Sexes/Victoria & Abdul (2017)_>,
#   'Academy Awards Spotlight for 2017 (2017)': <Movie id:4717068[http] title:_Academy Awards Spotlight for 2017 (2017)_>,
#   'The Space Between Us/I Am Not Your Negro/La La Land/Pinocchio Blu-ray/DVD (2017)': <Movie id:4647646[http] title:_The Space Between Us/I Am Not Your Negro/La La Land/Pinocchio Blu-ray/DVD (2017)_>,
#   'Rogue One: A Star Wars Story/La La Land/Collateral Beauty (2016)': <Movie id:4534016[http] title:_Rogue One: A Star Wars Story/La La Land/Collateral Beauty (2016)_>,
#   'Episode #10.6 (2014)': <Movie id:4175200[http] title:_Episode #10.6 (2014)_>,
#   'Episode #8.22 (2013)': <Movie id:2797286[http] title:_Episode #8.22 (2013)_>,
#   'Episode #8.15 (2013)': <Movie id:2631338[http] title:_Episode #8.15 (2013)_>,
#   'Episode #6.34 (2011)': <Movie id:2023002[http] title:_Episode #6.34 (2011)_>,
#   'The Jonathan Ross Show': <Movie id:2049323[http] title:_The Jonathan Ross Show (None)_>,
#   'Jeremy Clarkson/Steve Coogan/Alesha Dixon/Niall Horan/Anne-Marie/Emma Stone/Dame Emma Thompson (2021)': <Movie id:14747942[http] title:_Jeremy Clarkson/Steve Coogan/Alesha Dixon/Niall Horan/Anne-Marie/Emma Stone/Dame Emma Thompson (2021)_>,
#   "Kermode and Mayo's Film Review": <Movie id:5825482[http] title:_Kermode and Mayo's Film Review (None)_>,
#   'Emma Stone, Cruella, First Cow, The Conjuring III and Demon Slayer (2021)': <Movie id:15097422[http] title:_Emma Stone, Cruella, First Cow, The Conjuring III and Demon Slayer (2021)_>,
#   'Showterview with Jessi': <Movie id:14512490[http] title:_Showterview with Jessi (None)_>,
#   'A interview with Heroine Emma Stone in the movie Cruella. (2021)': <Movie id:15185998[http] title:_A interview with Heroine Emma Stone in the movie Cruella. (2021)_>,
#   "The Six O'Clock Show": <Movie id:14748656[http] title:_The Six O'Clock Show (None)_>,
#   'Episode dated 27 May 2021 (2021)': <Movie id:14748940[http] title:_Episode dated 27 May 2021 (2021)_>,
#   'Lorraine': <Movie id:0298674[http] title:_Lorraine (None)_>,
#   'Episode dated 26 May 2021 (2021)': <Movie id:15007584[http] title:_Episode dated 26 May 2021 (2021)_>,
#   'Episode dated 17 September 2018 (2018)': <Movie id:9040590[http] title:_Episode dated 17 September 2018 (2018)_>,
#   'Live with Kelly and Mark': <Movie id:0096636[http] title:_Live with Kelly and Mark (None)_>,
#   'Do It Week - Day 4 (2017)': <Movie id:7373446[http] title:_Do It Week - Day 4 (2017)_>,
#   "Live's Best Halloween Show Ever... Seriously (2014)": <Movie id:4143992[http] title:_Live's Best Halloween Show Ever... Seriously (2014)_>,
#   'Guest Co-Host Josh Groban/Emma Stone/Suzanne Somers/Neon Trees (2014)': <Movie id:4102938[http] title:_Guest Co-Host Josh Groban/Emma Stone/Suzanne Somers/Neon Trees (2014)_>,
#   'Emma Stone/Howie Mandel/Maia Mitchell (2014)': <Movie id:3957968[http] title:_Emma Stone/Howie Mandel/Maia Mitchell (2014)_>,
#   'Emma Stone/Keith Urban (2014)': <Movie id:3690376[http] title:_Emma Stone/Keith Urban (2014)_>,
#   'Episode dated 18 March 2013 (2013)': <Movie id:2777700[http] title:_Episode dated 18 March 2013 (2013)_>,
#   'Episode dated 27 June 2012 (2012)': <Movie id:2218406[http] title:_Episode dated 27 June 2012 (2012)_>,
#   'The Jess Cagle Podcast with Julia Cunningham': <Movie id:14739860[http] title:_The Jess Cagle Podcast with Julia Cunningham (None)_>,
#   'Hollywood First Look': <Movie id:6587354[http] title:_Hollywood First Look (None)_>,
#   'Episode #3.42 (2021)': <Movie id:14712508[http] title:_Episode #3.42 (2021)_>,
#   'Emma Stone/Ben Falcone/Josh Groban (2020)': <Movie id:13507924[http] title:_Emma Stone/Ben Falcone/Josh Groban (2020)_>,
#   'Emma Stone/Tracy Pollan/Michael J. Fox/Tank and the Bangas (2019)': <Movie id:10139742[http] title:_Emma Stone/Tracy Pollan/Michael J. Fox/Tank and the Bangas (2019)_>,
#   'Emma Stone/Bridget Everett/Finesse Mitchell (2018)': <Movie id:9228600[http] title:_Emma Stone/Bridget Everett/Finesse Mitchell (2018)_>,
#   'Emma Stone/Logan Lerman/Sam Smith (2014)': <Movie id:4107394[http] title:_Emma Stone/Logan Lerman/Sam Smith (2014)_>,
#   'Some Good News': <Movie id:12054924[http] title:_Some Good News (None)_>,
#   'The Office Cast Reunites for Zoom Wedding (2020)': <Movie id:12294096[http] title:_The Office Cast Reunites for Zoom Wedding (2020)_>,
#   'Celebrities with Heart': <Movie id:10329132[http] title:_Celebrities with Heart (None)_>,
#   'Valley Youth Theatre (2020)': <Movie id:10492560[http] title:_Valley Youth Theatre (2020)_>,
#   'Lights Out with David Spade': <Movie id:8129446[http] title:_Lights Out with David Spade (None)_>,
#   'Episode #1.43 (2019)': <Movie id:11120922[http] title:_Episode #1.43 (2019)_>,
#   'WatchMojo': <Movie id:2070564[http] title:_WatchMojo (None)_>,
#   'Zombieland: Double Tap Cast Answers Fan Questions (2019)': <Movie id:12014254[http] title:_Zombieland: Double Tap Cast Answers Fan Questions (2019)_>,
#   'The Mind, Explained': <Movie id:10810430[http] title:_The Mind, Explained (None)_>,
# ...
#   'Episode dated 1 October 2009 (2009)': <Movie id:1521364[http] title:_Episode dated 1 October 2009 (2009)_>,
#   'Episode dated 27 July 2009 (2009)': <Movie id:1480461[http] title:_Episode dated 27 July 2009 (2009)_>,
#   'The 66th Annual Tony Awards': <Movie id:2184336[http] title:_The 66th Annual Tony Awards (None)_>,
#   'Guys Choice Awards 2012': <Movie id:2202980[http] title:_Guys Choice Awards 2012 (None)_>,
#   '2012 MTV Movie Awards': <Movie id:2402919[http] title:_2012 MTV Movie Awards (None)_>,
#   "Nickelodeon Kids' Choice Awards 2012": <Movie id:2199495[http] title:_Nickelodeon Kids' Choice Awards 2012 (None)_>,
#   'Sleeping Dogs: Behind the Scenes': <Movie id:31158608[http] title:_Sleeping Dogs: Behind the Scenes (None)_>,
#   'The 84th Annual Academy Awards': <Movie id:2089826[http] title:_The 84th Annual Academy Awards (None)_>,
#   '18th Annual Screen Actors Guild Awards': <Movie id:2224007[http] title:_18th Annual Screen Actors Guild Awards (None)_>,
#   'The 69th Annual Golden Globe Awards': <Movie id:2125640[http] title:_The 69th Annual Golden Globe Awards (None)_>,
#   "17th Annual Critics' Choice Movie Awards": <Movie id:2184093[http] title:_17th Annual Critics' Choice Movie Awards (None)_>,
#   "The 38th Annual People's Choice Awards": <Movie id:2179173[http] title:_The 38th Annual People's Choice Awards (None)_>,
#   'Sesame Street': <Movie id:0063951[http] title:_Sesame Street (None)_>,
#   'Getting Centered (2011)': <Movie id:2146867[http] title:_Getting Centered (2011)_>,
#   'Días de cine': <Movie id:0390699[http] title:_Días de cine (None)_>,
#   'Episode dated 27 October 2011 (2011)': <Movie id:2097469[http] title:_Episode dated 27 October 2011 (2011)_>,
#   'The Big Picture': <Movie id:1908337[http] title:_The Big Picture (None)_>,
#   'The Help (2011)': <Movie id:2078359[http] title:_The Help (2011)_>,
#   'Teen Choice 2011': <Movie id:1991198[http] title:_Teen Choice 2011 (None)_>,
#   'Sidewalks Entertainment': <Movie id:0094547[http] title:_Sidewalks Entertainment (None)_>,
#   'Larry & Emma (2011)': <Movie id:2257861[http] title:_Larry & Emma (2011)_>,
#   '2011 MTV Movie Awards': <Movie id:1924211[http] title:_2011 MTV Movie Awards (None)_>,
#   'The 68th Annual Golden Globe Awards': <Movie id:1810776[http] title:_The 68th Annual Golden Globe Awards (None)_>,
#   "16th Annual Critics' Choice Movie Awards": <Movie id:1817076[http] title:_16th Annual Critics' Choice Movie Awards (None)_>,
#   'Easy A: The School of Pop Culture': <Movie id:1971384[http] title:_Easy A: The School of Pop Culture (None)_>,
#   'The Making of Easy A': <Movie id:1967629[http] title:_The Making of Easy A (None)_>,
#   'Vocabulary of Hilarity': <Movie id:1967658[http] title:_Vocabulary of Hilarity (None)_>,
#   'Rachael Ray': <Movie id:0827947[http] title:_Rachael Ray (None)_>,
#   'How to Stop Adult Temper Tantrums (2010)': <Movie id:1751489[http] title:_How to Stop Adult Temper Tantrums (2010)_>,
#   'Episode #5.5 (2010)': <Movie id:1734499[http] title:_Episode #5.5 (2010)_>,
#   'Chelsea Lately': <Movie id:1002838[http] title:_Chelsea Lately (None)_>,
#   'Episode #4.138 (2010)': <Movie id:2770692[http] title:_Episode #4.138 (2010)_>,
#   '2010 MTV Video Music Awards': <Movie id:1720618[http] title:_2010 MTV Video Music Awards (None)_>,
#   'iPhone Murder Apps': <Movie id:1741714[http] title:_iPhone Murder Apps (None)_>,
#   'Cinema 3': <Movie id:0111920[http] title:_Cinema 3 (None)_>,
#   'Episode dated 19 December 2009 (2009)': <Movie id:1569991[http] title:_Episode dated 19 December 2009 (2009)_>,
#   "Girls Upstairs: Making of 'House Bunny'": <Movie id:1356777[http] title:_Girls Upstairs: Making of 'House Bunny' (None)_>,
#   'Spike Guys Choice': <Movie id:1301718[http] title:_Spike Guys Choice (None)_>,
#   '2008 MTV Movie Awards': <Movie id:1230105[http] title:_2008 MTV Movie Awards (None)_>,
#   'Last Call with Carson Daly': <Movie id:0305056[http] title:_Last Call with Carson Daly (None)_>,
#   'Episode dated 7 August 2007 (2007)': <Movie id:1081478[http] title:_Episode dated 7 August 2007 (2007)_>,
#   'In Search of the Partridge Family': <Movie id:0408087[http] title:_In Search of the Partridge Family (None)_>,
#   'Finale (2004)': <Movie id:0871651[http] title:_Finale (2004)_>,
#   'Valliant Renegade': <Movie id:22884836[http] title:_Valliant Renegade (None)_>,
#   'The Walt DISNEY Company Annual ShareHolder Meeting 2024 | LIVE Coverage, Analysis, Reaction (2024)': <Movie id:31998102[http] title:_The Walt DISNEY Company Annual ShareHolder Meeting 2024 | LIVE Coverage, Analysis, Reaction (2024)_>,
#   'Josiah Rises': <Movie id:11465472[http] title:_Josiah Rises (None)_>,
#   'Elites PANIC After Police Get INVOLVED At The OSCARS! (2024)': <Movie id:31709268[http] title:_Elites PANIC After Police Get INVOLVED At The OSCARS! (2024)_>,
#   'Movie Night Extravaganza': <Movie id:15054972[http] title:_Movie Night Extravaganza (None)_>,
#   'Poor Things with Renee Ruin (2024)': <Movie id:31888088[http] title:_Poor Things with Renee Ruin (2024)_>,
#   'Zombieland with Bonnie Burton (2022)': <Movie id:23139656[http] title:_Zombieland with Bonnie Burton (2022)_>,
#   'Episode #43.134 (2024)': <Movie id:31242798[http] title:_Episode #43.134 (2024)_>,
#   'Episode #43.108 (2024)': <Movie id:30777479[http] title:_Episode #43.108 (2024)_>,
#   'Episode #43.102 (2024)': <Movie id:30777478[http] title:_Episode #43.102 (2024)_>,
#   'Episode #43.79 (2023)': <Movie id:30395554[http] title:_Episode #43.79 (2023)_>,
#   'Episode #43.78 (2023)': <Movie id:30183096[http] title:_Episode #43.78 (2023)_>,
#   'Episode #42.285 (2023)': <Movie id:28601446[http] title:_Episode #42.285 (2023)_>,
#   'Episode #42.222 (2023)': <Movie id:27641795[http] title:_Episode #42.222 (2023)_>,
#   'Episode #42.96 (2022)': <Movie id:23951372[http] title:_Episode #42.96 (2022)_>,
#   "ET's Marvel Takeover! (2022)": <Movie id:25134430[http] title:_ET's Marvel Takeover! (2022)_>,
#   'Episode #42.36 (2022)': <Movie id:22458780[http] title:_Episode #42.36 (2022)_>,
#   'Episode #41.66 (2021)': <Movie id:15850634[http] title:_Episode #41.66 (2021)_>,
#   'ET "F9" Blowout! (2021)': <Movie id:14889476[http] title:_ET "F9" Blowout! (2021)_>,
#   'Inside the IHeartRadio Music Awards! (2021)': <Movie id:14707136[http] title:_Inside the IHeartRadio Music Awards! (2021)_>,
#   'Episode #40.216 (2021)': <Movie id:14557078[http] title:_Episode #40.216 (2021)_>,
#   'Episode #40.204 (2021)': <Movie id:14557074[http] title:_Episode #40.204 (2021)_>,
#   'Episode #40.177 (2021)': <Movie id:14385970[http] title:_Episode #40.177 (2021)_>,
#   'Episode #40.128 (2021)': <Movie id:13997642[http] title:_Episode #40.128 (2021)_>,
#   'ET Thanksgiving! (2020)': <Movie id:13510936[http] title:_ET Thanksgiving! (2020)_>,
#   'Episode #40.60 (2020)': <Movie id:13385784[http] title:_Episode #40.60 (2020)_>,
#   'Episode #40.48 (2020)': <Movie id:13385780[http] title:_Episode #40.48 (2020)_>,
#   'Brad Pitt (2020)': <Movie id:12381310[http] title:_Brad Pitt (2020)_>,
#   'Episode #39.78 (2019)': <Movie id:11360478[http] title:_Episode #39.78 (2019)_>,
#   'We Spy Will Smith and Tom Holland! (2019)': <Movie id:11369630[http] title:_We Spy Will Smith and Tom Holland! (2019)_>,
#   'Big Brother Exclusive! (2019)': <Movie id:10528840[http] title:_Big Brother Exclusive! (2019)_>,
#   'Episode #38.144 (2019)': <Movie id:9668974[http] title:_Episode #38.144 (2019)_>,
#   'Episode #38.61 (2018)': <Movie id:9296640[http] title:_Episode #38.61 (2018)_>,
#   'Episode #38.19 (2018)': <Movie id:9065408[http] title:_Episode #38.19 (2018)_>,
#   'Episode #37.304 (2018)': <Movie id:8897748[http] title:_Episode #37.304 (2018)_>,
#   'Episode #37.303 (2018)': <Movie id:8897746[http] title:_Episode #37.303 (2018)_>,
#   'Episode #37.257 (2018)': <Movie id:8401310[http] title:_Episode #37.257 (2018)_>,
#   'Episode #37.173 (2018)': <Movie id:8185508[http] title:_Episode #37.173 (2018)_>,
#   'Episode #37.111 (2018)': <Movie id:7866964[http] title:_Episode #37.111 (2018)_>,
#   'Episode #37.102 (2018)': <Movie id:7803652[http] title:_Episode #37.102 (2018)_>,
#   'Episode #37.90 (2017)': <Movie id:7683660[http] title:_Episode #37.90 (2017)_>,
#   'Episode #37.86 (2017)': <Movie id:7765504[http] title:_Episode #37.86 (2017)_>,
#   'Episode #37.55 (2017)': <Movie id:7448554[http] title:_Episode #37.55 (2017)_>,
#   'Episode #37.40 (2017)': <Movie id:7540034[http] title:_Episode #37.40 (2017)_>,
#   'Episode #37.19 (2017)': <Movie id:7448558[http] title:_Episode #37.19 (2017)_>,
#   'Episode #36.312 (2017)': <Movie id:7301454[http] title:_Episode #36.312 (2017)_>,
#   'Episode #36.291 (2017)': <Movie id:7248558[http] title:_Episode #36.291 (2017)_>,
#   'Episode #36.150 (2017)': <Movie id:6577640[http] title:_Episode #36.150 (2017)_>,
#   'Episode #36.146 (2017)': <Movie id:6551940[http] title:_Episode #36.146 (2017)_>,
#   'Episode #36.144 (2017)': <Movie id:6480084[http] title:_Episode #36.144 (2017)_>,
#   'Episode #36.118 (2017)': <Movie id:6451214[http] title:_Episode #36.118 (2017)_>,
#   'Episode #36.108 (2017)': <Movie id:6363444[http] title:_Episode #36.108 (2017)_>,
#   'Episode #36.102 (2017)': <Movie id:6363438[http] title:_Episode #36.102 (2017)_>,
#   'Episode #36.101 (2017)': <Movie id:6374628[http] title:_Episode #36.101 (2017)_>,
#   'Episode #36.84 (2016)': <Movie id:6275662[http] title:_Episode #36.84 (2016)_>,
#   'Episode #36.79 (2016)': <Movie id:6288782[http] title:_Episode #36.79 (2016)_>,
#   'Episode dated 25 November 2015 (2015)': <Movie id:5217596[http] title:_Episode dated 25 November 2015 (2015)_>,
#   'Episode dated 28 May 2015 (2015)': <Movie id:4704430[http] title:_Episode dated 28 May 2015 (2015)_>,
#   'Episode dated 26 May 2015 (2015)': <Movie id:4704420[http] title:_Episode dated 26 May 2015 (2015)_>,
#   'Episode dated 15 May 2015 (2015)': <Movie id:4668148[http] title:_Episode dated 15 May 2015 (2015)_>,
#   'Episode dated 2 May 2015 (2015)': <Movie id:4631770[http] title:_Episode dated 2 May 2015 (2015)_>,
#   'The Project': <Movie id:1480165[http] title:_The Project (None)_>,
#   'Episode dated 8 January 2024 (2024)': <Movie id:30818587[http] title:_Episode dated 8 January 2024 (2024)_>,
#   'Nudes in the News': <Movie id:11719236[http] title:_Nudes in the News (None)_>,
#   'Show #509 (2023)': <Movie id:30497571[http] title:_Show #509 (2023)_>,
#   'Nerdrotic': <Movie id:11101140[http] title:_Nerdrotic (None)_>,
#   'Why Woke Hollywood is FAILING (2023)': <Movie id:27661951[http] title:_Why Woke Hollywood is FAILING (2023)_>,
#   'What 16 Movies Looked Like Behind the Scenes in 2021': <Movie id:20115632[http] title:_What 16 Movies Looked Like Behind the Scenes in 2021 (None)_>,
#   'Moments Within Moments': <Movie id:15277036[http] title:_Moments Within Moments (None)_>,
#   'Inside Edition Weekend': <Movie id:11489716[http] title:_Inside Edition Weekend (None)_>,
#   'Episode #33.37 (2021)': <Movie id:14519060[http] title:_Episode #33.37 (2021)_>,
#   'Allen v. Farrow': <Movie id:13990468[http] title:_Allen v. Farrow (None)_>,
#   'Episode Four (2021)': <Movie id:14001862[http] title:_Episode Four (2021)_>,
#   'Regis Farewell Celebration Special (2020)': <Movie id:12736296[http] title:_Regis Farewell Celebration Special (2020)_>,
#   'After Oscar Show/Neil Patrick Harris/Flo Rida (2015)': <Movie id:4464250[http] title:_After Oscar Show/Neil Patrick Harris/Flo Rida (2015)_>,
#   'Episode #25.253 (2013)': <Movie id:3125888[http] title:_Episode #25.253 (2013)_>,
#   'Episode #5.71 (2019)': <Movie id:11400944[http] title:_Episode #5.71 (2019)_>,
#   'Episode #4.226 (2019)': <Movie id:10628408[http] title:_Episode #4.226 (2019)_>,
#   'Episode #4.26 (2018)': <Movie id:8963190[http] title:_Episode #4.26 (2018)_>,
#   'Episode #3.247 (2018)': <Movie id:8657546[http] title:_Episode #3.247 (2018)_>,
#   'Episode #3.231 (2018)': <Movie id:8599016[http] title:_Episode #3.231 (2018)_>,
#   'Episode #2.213 (2017)': <Movie id:7024310[http] title:_Episode #2.213 (2017)_>,
#   'Episode #2.205 (2017)': <Movie id:6968558[http] title:_Episode #2.205 (2017)_>,
#   'Saturday Night Live Christmas Special': <Movie id:22506502[http] title:_Saturday Night Live Christmas Special (None)_>,
#   'A Saturday Night Live Christmas Special (2019)': <Movie id:11306452[http] title:_A Saturday Night Live Christmas Special (2019)_>,
#   'Untouchable': <Movie id:9358228[http] title:_Untouchable (None)_>,
#   'The Bill Murray Stories: Life Lessons Learned from a Mythical Man': <Movie id:7329810[http] title:_The Bill Murray Stories: Life Lessons Learned from a Mythical Man (None)_>,
#   'Episode dated 11 October 2017 (2017)': <Movie id:7470092[http] title:_Episode dated 11 October 2017 (2017)_>,
#   'Episode dated 27 February 2017 (2017)': <Movie id:6594286[http] title:_Episode dated 27 February 2017 (2017)_>,
#   'Episode dated 30 January 2017 (2017)': <Movie id:6481114[http] title:_Episode dated 30 January 2017 (2017)_>,
#   'Episode dated 9 January 2017 (2017)': <Movie id:6426238[http] title:_Episode dated 9 January 2017 (2017)_>,
#   'Episode #23.220 (2017)': <Movie id:6886606[http] title:_Episode #23.220 (2017)_>,
#   'Episode #23.156 (2017)': <Movie id:6577736[http] title:_Episode #23.156 (2017)_>,
#   'Episode #23.144 (2017)': <Movie id:6477944[http] title:_Episode #23.144 (2017)_>,
#   'Episode #23.126 (2017)': <Movie id:6363568[http] title:_Episode #23.126 (2017)_>,
#   'Episode #23.114 (2017)': <Movie id:6363562[http] title:_Episode #23.114 (2017)_>,
#   'Episode #23.113 (2017)': <Movie id:6401322[http] title:_Episode #23.113 (2017)_>,
#   'Episode #23.109 (2017)': <Movie id:6374660[http] title:_Episode #23.109 (2017)_>,
#   'Episode #23.85 (2016)': <Movie id:6137922[http] title:_Episode #23.85 (2016)_>,
#   'Episode #23.36 (2016)': <Movie id:6095294[http] title:_Episode #23.36 (2016)_>,
#   'Episode #22.57 (2015)': <Movie id:5218054[http] title:_Episode #22.57 (2015)_>,
#   'Episode dated 4 July 2015 (2015)': <Movie id:4810610[http] title:_Episode dated 4 July 2015 (2015)_>,
#   'Episode dated 30 May 2015 (2015)': <Movie id:4634002[http] title:_Episode dated 30 May 2015 (2015)_>,
#   'Episode dated 21 February 2015 (2015)': <Movie id:4402318[http] title:_Episode dated 21 February 2015 (2015)_>,
#   'Episode dated 7 February 2015 (2015)': <Movie id:4402308[http] title:_Episode dated 7 February 2015 (2015)_>,
#   'Episode #13.150 (2017)': <Movie id:6577764[http] title:_Episode #13.150 (2017)_>,
#   'Episode #13.120 (2017)': <Movie id:6451140[http] title:_Episode #13.120 (2017)_>,
#   'Episode #13.108 (2017)': <Movie id:6401204[http] title:_Episode #13.108 (2017)_>,
#   'Episode #13.84 (2016)': <Movie id:6327030[http] title:_Episode #13.84 (2016)_>,
#   'Compilation Show (2017)': <Movie id:6578528[http] title:_Compilation Show (2017)_>,
#   'Compilation (2014)': <Movie id:3833416[http] title:_Compilation (2014)_>,
#   'Breakfast': <Movie id:0262152[http] title:_Breakfast (None)_>,
#   'Nunca es tarde': <Movie id:4699262[http] title:_Nunca es tarde (None)_>,
#   'Episode #21.139 (2017)': <Movie id:6513450[http] title:_Episode #21.139 (2017)_>,
#   'Episode #21.126 (2017)': <Movie id:6447346[http] title:_Episode #21.126 (2017)_>,
#   'Hoy nos toca': <Movie id:6436780[http] title:_Hoy nos toca (None)_>,
#   'Episode dated 13 February 2017 (2017)': <Movie id:6553394[http] title:_Episode dated 13 February 2017 (2017)_>,
#   'Episode dated 26 January 2017 (2017)': <Movie id:6474918[http] title:_Episode dated 26 January 2017 (2017)_>,
#   'Nostalgia Critic': <Movie id:1635327[http] title:_Nostalgia Critic (None)_>,
#   'When Are Critics Wrong? (2016)': <Movie id:5592538[http] title:_When Are Critics Wrong? (2016)_>,
#   'Inside Edition': <Movie id:0166442[http] title:_Inside Edition (None)_>,
#   'Episode #26.144 (2015)': <Movie id:4539024[http] title:_Episode #26.144 (2015)_>,
#   'An SNL Valentine': <Movie id:4460272[http] title:_An SNL Valentine (None)_>,
#   'Flirting with Danger': <Movie id:2894120[http] title:_Flirting with Danger (None)_>,
#   'November 2011 (2011)': <Movie id:2098453[http] title:_November 2011 (2011)_>},
#  'namesRefs': {'Emma Stone': <Person id:1297015[http] name:_Emma Stone_>}}

# %% [markdown]
# Vemos que esto es un diccionario y es por eso que el tutorial nos sugiere hacer este camino (aunque tuve que hacerle una edición):

# %%
# printing movie name
for index in range(15):
    movie_name = actor_results['data']['filmography']['actress'][index]
    print(movie_name)
# Out:
# Cruella 2
# Untitled Yorgos Lanthimos Remake Project
# Eddington
# Kinds of Kindness
# The Curse
# Poor Things
# Bleat
# Saturday Morning All Star Hits!
# Cruella
# Dear Diary: World's First Pranks
# The Croods: A New Age
# Louis Vuitton: Coeur Battant
# Zombieland: Double Tap
# Paul McCartney: Who Cares
# Let's Dance

# %% [markdown]
# Cerremos, con otro ejemplo.
#
# Veamos cuántas temporadas tiene una serie:

# %%
search_movie = ia.search_movie('Breaking Bad')
search_movie[0]
# Out:
# <Movie id:0903747[http] title:_"Breaking Bad" (2013) (2008)_>

# %%
# id 
code = "0903747"
  
# getting information 
series = ia.get_movie(code) 
  
# getting seasons of the series 
season = series.data['seasons'] 
  
# printing the object i.e name 
print(series) 
  
# print the seasons 
print(season)
# Out:
# Breaking Bad
# ['1', '2', '3', '4', '5']
